# %%
import pandas as pd
import numpy as np

from services.tables.create_info_table import employee_info_df

employee_info_df
# Out:
# 🔧 [DEV MODE] 개발 모드 활성화:
#    - 직원 수: 1000명
#    - 날짜 범위: 2020-01-01 ~ 현재
#    - 예상 로딩 속도: 프로덕션 수준 (대용량 데이터)
#          사번   이름        입사일자                 소속 본부                   소속 실  \
# 0    E00001  김수민  2014-04-16     Planning Division        Strategy Office
# 1    E00002  송지민  2020-06-25        Sales Division  Domestic Sales Office
# 2    E00003  이종수  2022-02-22     Planning Division        Strategy Office
# 3    E00004  이은서  2025-03-25     Planning Division         Finance Office
# 4    E00005  최예지  2014-12-15    Operating Division     Engineering Office
# ..      ...  ...         ...                   ...                    ...
# 995  E00996  허혜진  2023-08-03    Operating Division      Production Office
# 996  E00997  오민수  2022-05-19        Sales Division    Global Sales Office
# 997  E00998  홍지우  2023-01-01  Development Division              QA Office
# 998  E00999  서지은  2013-02-10  Development Division             R&D Office
# ...
